# %%
import os
import pandas as pd
import requests
import time

def load_table(table_name, batch_size=1000, pause=0.5, max_batch=None):
    base_url = f'https://data.epa.gov/efservice/{table_name}/{{start}}:{{end}}/JSON'
    todos_los_datos = []
    start = 1
    lote = 0

    while True:
        end = start + batch_size - 1
        url = base_url.format(start=start, end=end)
        print(f"Descargando: {table_name} [{start}:{end}]")

        try:
            response = requests.get(url, timeout=30)
            response.raise_for_status()
            data = response.json()
        except Exception as e:
            print(f" Error en el request: {e}")
            break

        if not data:
            print(" Fin de los datos.")
            break

        todos_los_datos.extend(data)
        start += batch_size
        lote += 1

        if max_batch and lote >= max_batch:
            print(f" Límite de lotes alcanzado ({max_batch})")
            break

        time.sleep(pause)

    return pd.DataFrame(todos_los_datos)

def cargar_o_actualizar_tabla(nombre_tabla, carpeta='epa_cache', forzar_actualizacion=False):
    os.makedirs(carpeta, exist_ok=True)
    ruta_archivo = os.path.join(carpeta, f"{nombre_tabla}.csv")

    if os.path.exists(ruta_archivo) and not forzar_actualizacion:
        print(f"📁 Leyendo desde cache: {ruta_archivo}")
        return pd.read_csv(ruta_archivo)

    print(f"🔄 Descargando datos desde la API para: {nombre_tabla}")
    df = load_table(nombre_tabla)

    print(f"💾 Guardando cache local en: {ruta_archivo}")
    df.to_csv(ruta_archivo, index=False)

    return df

# Cargar tabla de instalaciones
df_facilities = cargar_o_actualizar_tabla("ghg.rlps_ghg_emitter_facilities")

# Cargar tabla de emisiones por gas
df_emissions = cargar_o_actualizar_tabla("ghg.EF_W_EMISSIONS_SOURCE_GHG")
# Out:
# 📁 Leyendo desde cache: epa_cache\ghg.rlps_ghg_emitter_facilities.csv
# 📁 Leyendo desde cache: epa_cache\ghg.EF_W_EMISSIONS_SOURCE_GHG.csv

# %%
df_emissions = cargar_o_actualizar_tabla("ghg.EF_W_EMISSIONS_SOURCE_GHG", forzar_actualizacion=True)
df_facilities = cargar_o_actualizar_tabla("ghg.rlps_ghg_emitter_facilities", forzar_actualizacion=True)

# %%
url = 'https://data.epa.gov/efservice/ghg.rlps_ghg_emitter_facilities/1:100/JSON'
df_emissions = pd.read_json(url)

df_emissions.head()
# Out:
#    add_naics_code                address1  address2 cems_used      city  \
# 0             NaN  5105 LAKE TERRELL ROAD       NaN      None  FERNDALE
# 1             NaN  5105 LAKE TERRELL ROAD       NaN      None  FERNDALE
# 2             NaN  5105 LAKE TERRELL ROAD       NaN      None  FERNDALE
# 3             NaN  5105 LAKE TERRELL ROAD       NaN      None  FERNDALE
# 4             NaN  5105 LAKE TERRELL ROAD       NaN      None  FERNDALE
#
#   cogen_unit_emm_ind          county  county_fips epa_verified  facility_id  \
# 0                  Y  WHATCOM COUNTY        53073         None      1000001
# 1                  Y  WHATCOM COUNTY        53073         None      1000001
# 2                  N  WHATCOM COUNTY        53073         None      1000001
# 3                  N  WHATCOM COUNTY        53073            Y      1000001
# 4                  N  WHATCOM COUNTY        53073         None      1000001
#
#    ...   latitude   longitude  \
# 0  ...  48.828707 -122.685533
# 1  ...  48.828707 -122.685533
# 2  ...  48.828707 -122.685533
# 3  ...  48.828707 -122.685533
# 4  ...  48.828707 -122.685533
#
#                                       parent_company plant_code primary_naics  \
# 0  EMPECO IV, LLC AND USPF II FERNDALE HOLDINGS, ...       None        221112
# 1  EMPECO IV, LLC AND USPF II FERNDALE HOLDINGS, ...       None        221112
# 2                          PUGET SOUND ENERGY (100%)       None        221112
# 3                          PUGET SOUND ENERGY (100%)          Y        221112
# 4                          PUGET SOUND ENERGY (100%)          Y        221112
#
#    secondary_naics  state  state_name  year    zip
# 0              NaN     WA  WASHINGTON  2010  98248
# 1              NaN     WA  WASHINGTON  2011  98248
# 2              NaN     WA  WASHINGTON  2012  98248
# 3              NaN     WA  WASHINGTON  2013  98248
# 4              NaN     WA  WASHINGTON  2014  98248
#
# [5 rows x 21 columns]

# %%
url = 'https://data.epa.gov/efservice/ghg.EF_W_EMISSIONS_SOURCE_GHG/1:100/JSON'
df_emissions = pd.read_json(url)

df_emissions.head(50)
# Out:
#                              bamm_desc_source_summary  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16  According to 40 CFR 98.233(o)(1)(iii)(A):  For...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25  API parameters were either default, based on c...
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                                N/A
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
#
#    bamm_indicator_source_summary  \
# 0                           None
# 1                           None
# 2                           None
# 3                           None
# 4                           None
# 5                             No
# 6                           None
# 7                           None
# 8                           None
# 9                           None
# 10                          None
# 11                          None
# 12                          None
# 13                          None
# 14                          None
# 15                            No
# 16                           Yes
# 17                          None
# 18                          None
# 19                          None
# 20                          None
# 21                          None
# 22                          None
# 23                          None
# 24                          None
# 25                            No
# 26                          None
# 27                          None
# 28                          None
# 29                            No
# 30                          None
# 31                            No
# 32                            No
# 33                          None
# 34                            No
# 35                          None
# 36                          None
# 37                          None
# 38                          None
# 39                          None
# 40                          None
# 41                          None
# 42                          None
# 43                          None
# 44                          None
# 45                          None
# 46                          None
# 47                          None
# 48                          None
# 49                          None
#
#                        basin_associated_with_facility  facility_id  \
# 0                                                None      1003447
# 1                                                None      1004777
# 2                     220 - Gulf Coast Basin (LA, TX)      1009706
# 3                                                None      1012154
# 4                                                None      1004849
# 5                                                          1009659
# 6                                                None      1011274
# 7                                  540 - Denver Basin      1009354
# 8                                                None      1004400
# 9                                                None      1003535
# 10                                               None      1006483
# 11                                               None      1012467
# 12                                               None      1008132
# 13                                               None      1010492
# 14                                               None      1014355
# 15                                                         1006884
# 16                                                         1003287
# 17                                               None      1012817
# 18                                               None      1002825
# 19                                               None      1006503
# 20                                               None      1007377
# 21                                               None      1010559
# 22                                                         1008693
# 23                                               None      1013194
# 24                                               None      1004163
# 25                                                         1008363
# 26                                               None      1008132
# 27                                               None      1013753
# 28                                               None      1012731
# 29                                                         1008405
# 30                                               None      1012256
# 31                                                         1008956
# 32                                                         1008286
# 33                                               None      1004642
# 34                                                         1006505
# 35                                               None      1014094
# 36                             730 - Sacramento Basin      1008405
# 37                              435 - Palo Duro Basin      1012952
# 38  160A - Appalachian Basin (Eastern Overthrust A...      1012537
# 39                                               None      1008826
# 40                                               None      1013957
# 41                                               None      1013565
# 42                                430 - Permian Basin      1012129
# 43                                430 - Permian Basin      1014071
# 44                                               None      1014691
# 45                               360 - Anadarko Basin      1011666
# 46                               740 - Coastal Basins      1002978
# 47                                               None      1004394
# 48                    220 - Gulf Coast Basin (LA, TX)      1008293
# 49                                               None      1009464
#
#                                         facility_name  \
# 0         UGC - DRAGON TRAIL GAS PLANT - 08-103-00036
# 1   Great Lakes Gas Transmission Pipeline Shevlin ...
# 2                SilverBow Resources, LLC - Basin 220
# 3             580 - San Juan Basin Gathering/Boosting
# 4                 CONROE NATURAL GAS PROCESSING PLANT
# 5     Enervest Operating, L.L.C. 260 East Texas Basin
# 6               Kensington Cryogenic Processing Plant
# 7   HighPoint Operating Corporation - Denver Basin...
# 8                Springridge South Compressor Station
# 9   Eastern Gas Transmission and Storage - Hasting...
# 10  Scissortail Energy Featherston Station Quinton...
# 11             EQM Olympus Midstream LLC - Basin 160A
# 12                            Stanley Booster Station
# 13                        SNG Station 5259 Auburn, AL
# 14                           SCM Gathering & Boosting
# 15      Southwest Royalties, Inc. - 430 Permian Basin
# 16                          Panola Compressor Station
# 17                                    DGC - Arkoma BG
# 18         FLORIDA GAS TRANSMISSION COMPANY - LECANTO
# 19                             DTE Energy Michcon LDC
# 20                                 Crescent Gas Plant
# 21             EPNG Station 6595 Washington Ranch, NM
# 22                                 Noekle 430 Permian
# 23                             Rover - Mainline CS #3
# 24                                          NICOR GAS
# 25  Riviera Resources 305 Michigan Basin Productio...
# 26                            Stanley Booster Station
# 27                 Freeport LNG Pretreatment Facility
# 28                           EnLink Anadarko #360-G&B
# 29  California Resources Production Corporation  S...
# 30  HEP Pennsylvania Gathering LLC Midstream (160A...
# 31                     Chevron MCA 360 Anadarko Basin
# 32                        355 Chautauqua Platform DEC
# 33                        Minden Gas Processing Plant
# 34                          TOWNER COMPRESSOR STATION
# 35                            Waha Compressor Station
# 36  California Resources Production Corporation  S...
# 37                 SEP Palo Duro Basin 435 Production
# 38                       Northeast Natural Energy LLC
# 39                              Majorsville Gas Plant
# 40                  Panther Creek Processing Facility
# 41                       TGP Station 875 Richmond, KY
# 42                    Callon Permian Basin Operations
# 43                           VTX Energy Operating LLC
# 44                               PSE&G Burlington LNG
# 45                               Lindsay Field Office
# 46                  Arroyo Grande Production Facility
# 47                                    GB 783 Magnolia
# 48  Marathon Oil EF - Gulf Coast Basin (AAPG Basin...
# 49           Gulf South Pipeline - Marksville Station
#
#                                      industry_segment  \
# 0       Onshore natural gas processing [98.230(a)(3)]
# 1   Onshore natural gas transmission compression [...
# 2   Onshore petroleum and natural gas production [...
# 3   Onshore petroleum and natural gas gathering an...
# 4       Onshore natural gas processing [98.230(a)(3)]
# 5   Onshore petroleum and natural gas production [...
# 6       Onshore natural gas processing [98.230(a)(3)]
# 7   Onshore petroleum and natural gas production [...
# 8       Onshore natural gas processing [98.230(a)(3)]
# 9   Onshore natural gas transmission compression [...
# 10      Onshore natural gas processing [98.230(a)(3)]
# 11  Onshore petroleum and natural gas gathering an...
# 12      Onshore natural gas processing [98.230(a)(3)]
# 13  Onshore natural gas transmission compression [...
# 14  Onshore petroleum and natural gas gathering an...
# 15  Onshore petroleum and natural gas production [...
# 16  Onshore natural gas transmission compression [...
# 17  Onshore petroleum and natural gas gathering an...
# 18  Onshore natural gas transmission compression [...
# 19            Natural gas distribution [98.230(a)(8)]
# 20      Onshore natural gas processing [98.230(a)(3)]
# 21     Underground natural gas storage [98.230(a)(5)]
# 22  Onshore petroleum and natural gas production [...
# 23  Onshore natural gas transmission compression [...
# 24            Natural gas distribution [98.230(a)(8)]
# 25  Onshore petroleum and natural gas production [...
# 26      Onshore natural gas processing [98.230(a)(3)]
# 27      Onshore natural gas processing [98.230(a)(3)]
# 28  Onshore petroleum and natural gas gathering an...
# 29  Onshore petroleum and natural gas production [...
# 30  Onshore petroleum and natural gas gathering an...
# 31  Onshore petroleum and natural gas production [...
# 32  Onshore petroleum and natural gas production [...
# 33      Onshore natural gas processing [98.230(a)(3)]
# 34  Onshore natural gas transmission compression [...
# 35  Onshore natural gas transmission compression [...
# 36  Onshore petroleum and natural gas production [...
# 37  Onshore petroleum and natural gas production [...
# 38  Onshore petroleum and natural gas production [...
# 39      Onshore natural gas processing [98.230(a)(3)]
# 40      Onshore natural gas processing [98.230(a)(3)]
# 41  Onshore natural gas transmission compression [...
# 42  Onshore petroleum and natural gas production [...
# 43  Onshore petroleum and natural gas production [...
# 44  Liquefied natural gas (LNG) storage [98.230(a)...
# 45  Onshore petroleum and natural gas production [...
# 46  Onshore petroleum and natural gas production [...
# 47  Offshore petroleum and natural gas production ...
# 48  Onshore petroleum and natural gas production [...
# 49  Onshore natural gas transmission compression [...
#
#                                    reporting_category  reporting_year  \
# 0   Enhanced Oil Recovery Hydrocarbon Liquids [98....            2016
# 1   Completions and Workovers with Hydraulic Fract...            2023
# 2   Completions and Workovers without Hydraulic Fr...            2020
# 3                             Dehydrators [98.236(e)]            2018
# 4               Reciprocating Compressors [98.236(p)]            2015
# 5                  AssociatedGasVentingFlaringDetails            2014
# 6                  Acid Gas Removal Units [98.236(d)]            2022
# 7   Equipment Leaks Surveys and Population Counts ...            2015
# 8                 Centrifugal Compressors [98.236(o)]            2023
# 9      Associated Gas Venting and Flaring [98.236(m)]            2018
# 10  Offshore Petroleum and Natural Gas Production ...            2019
# 11  Enhanced Oil Recovery Hydrocarbon Liquids [98....            2021
# 12  Offshore Petroleum and Natural Gas Production ...            2018
# 13  Combustion Equipment at Onshore Petroleum and ...            2022
# 14                Centrifugal Compressors [98.236(o)]            2022
# 15                    WellCompletionsWorkoversDetails            2011
# 16                      CentrifugalCompressorsDetails            2014
# 17               Facility Overview [98.236(aa)(2-11)]            2023
# 18  Equipment Leaks Surveys and Population Counts ...            2017
# 19             Transmission Storage Tanks [98.236(k)]            2016
# 20  Enhanced Oil Recovery Hydrocarbon Liquids [98....            2021
# 21  Offshore Petroleum and Natural Gas Production ...            2015
# 22                                 WellVentingDetails            2011
# 23              Reciprocating Compressors [98.236(p)]            2020
# 24  Offshore Petroleum and Natural Gas Production ...            2018
# 25                            AtmosphericTanksDetails            2013
# 26             Transmission Storage Tanks [98.236(k)]            2020
# 27                 Acid Gas Removal Units [98.236(d)]            2020
# 28     Well Venting for Liquids Unloading [98.236(f)]            2023
# 29                         CombustionEmissionsDetails            2012
# 30  Completions and Workovers with Hydraulic Fract...            2017
# 31                            AtmosphericTanksDetails            2013
# 32                         AcidGasRemovalUnitsDetails            2014
# 33                                Sub-Basin Selection            2015
# 34            OtherEmissionsFromEquipmentLeaksDetails            2013
# 35     Associated Gas Venting and Flaring [98.236(m)]            2022
# 36     Well Venting for Liquids Unloading [98.236(f)]            2019
# 37                           Well Testing [98.236(l)]            2021
# 38     Well Venting for Liquids Unloading [98.236(f)]            2023
# 39              Atmospheric Storage Tanks [98.236(j)]            2016
# 40                   Blowdown Vent Stacks [98.236(i)]            2022
# 41              Atmospheric Storage Tanks [98.236(j)]            2021
# 42             Transmission Storage Tanks [98.236(k)]            2022
# 43                 Onshore Production [98.236(aa)(1)]            2020
# 44  Completions and Workovers with Hydraulic Fract...            2023
# 45  Completions and Workovers without Hydraulic Fr...            2016
# 46                Centrifugal Compressors [98.236(o)]            2022
# 47                            Dehydrators [98.236(e)]            2023
# 48          Natural Gas Pneumatic Devices [98.236(b)]            2022
# 49     Natural Gas Driven Pneumatic Pumps [98.236(c)]            2021
#
#     total_reported_ch4_emissions  total_reported_co2_emissions  \
# 0                            NaN                           0.0
# 1                       0.000000                           0.0
# 2                       0.000000                           0.0
# 3                    3770.830000                        1223.8
# 4                      73.020000                           4.4
# 5                       0.000000                           0.0
# 6                            NaN                        3594.8
# 7                      18.750000                           1.7
# 8                       0.000000                           0.0
# 9                       0.000000                           0.0
# 10                      0.000000                           0.0
# 11                           NaN                           0.0
# 12                      0.000000                           0.0
# 13                      0.000000                           0.0
# 14                      0.000000                           0.0
# 15                      0.000000                           0.0
# 16                      2.788000                           0.1
# 17                           NaN                           NaN
# 18                      5.380000                           0.2
# 19                      0.000000                           0.0
# 20                           NaN                           0.0
# 21                      0.000000                           0.0
# 22                      0.000000                           0.0
# 23                    115.140000                           3.3
# 24                      0.000000                           0.0
# 25                      0.756000                           0.6
# 26                      0.000000                           0.0
# 27                           NaN                      200022.9
# 28                      0.000000                           0.0
# 29                      1.180952                      109204.7
# 30                      0.000000                           0.0
# 31                      9.256000                          47.5
# 32                           NaN                           0.0
# 33                      0.000000                           0.0
# 34                      9.804000                           0.3
# 35                      0.000000                           0.0
# 36                     69.190000                           0.2
# 37                      0.000000                           0.0
# 38                      9.220000                           0.1
# 39                      0.000000                           0.0
# 40                      5.520000                           0.1
# 41                      0.000000                           0.0
# 42                      0.000000                           0.0
# 43                           NaN                           NaN
# 44                      0.000000                           0.0
# 45                      0.210000                           0.0
# 46                      0.000000                           0.0
# 47                      0.000000                           0.0
# 48                   6350.590000                         408.2
# 49                      0.000000                           0.0
#
#     total_reported_n2o_emissions
# 0                            NaN
# 1                       0.000000
# 2                       0.000000
# 3                       0.000000
# 4                            NaN
# 5                       0.000000
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                       0.000000
# 10                      0.000000
# 11                           NaN
# 12                      0.000000
# 13                      0.000000
# 14                           NaN
# 15                      0.000000
# 16                      0.000000
# 17                           NaN
# 18                           NaN
# 19                      0.000000
# 20                           NaN
# 21                      0.000000
# 22                      0.000000
# 23                           NaN
# 24                      0.000000
# 25                      0.000000
# 26                      0.000000
# 27                           NaN
# 28                           NaN
# 29                      0.117419
# 30                      0.000000
# 31                      0.000000
# 32                           NaN
# 33                      0.000000
# 34                           NaN
# 35                      0.000000
# 36                           NaN
# 37                      0.000000
# 38                           NaN
# 39                      0.000000
# 40                           NaN
# 41                      0.000000
# 42                      0.000000
# 43                           NaN
# 44                      0.000000
# 45                      0.000000
# 46                           NaN
# 47                      0.000000
# 48                           NaN
# 49                           NaN

# %%
df = pd.merge(df_facilities, df_emissions, on='facility_id', how='left')

df.head(10)

# %%
import plotly.graph_objects as go

df_emissions = df_emissions[['reporting_year', 'industry_segment', 'total_reported_ch4_emissions']].copy()
df_emissions.dropna(subset=['reporting_year', 'industry_segment', 'total_reported_ch4_emissions'], inplace=True)

# Agrupamos por año y segmento
grouped = df_emissions.groupby(['reporting_year', 'industry_segment'])['total_reported_ch4_emissions'].sum().reset_index()

# Pivot para tener columnas por industry_segment (para graficar apilado)
pivoted = grouped.pivot(index='reporting_year', columns='industry_segment', values='total_reported_ch4_emissions')
pivoted.fillna(0, inplace=True)

fig = go.Figure()

for segment in pivoted.columns:
    fig.add_trace(
        go.Bar(
            x=pivoted.index,
            y=pivoted[segment],
            name=segment
        )
    )

fig.update_layout(
    barmode='stack',
    title='Methane Emissions vs Year (Stacked by Industry Segment)',
    xaxis_title='Year',
    yaxis_title='Methane Emissions (tons)',
    legend_title='Industry Segment',
    height=600
)

fig.show()

# %%
df_emissions.groupby('reporting_year')['total_reported_ch4_emissions'].sum().plot(kind='bar', title='Total CH4 Emissions per Year')

# %%
df_emissions[df_emissions['reporting_year'] == 2019].groupby('industry_segment')['total_reported_ch4_emissions'].sum().sort_values(ascending=False).head(10)
